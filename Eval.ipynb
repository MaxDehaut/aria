# %%
print('Try and proof me')

# %%
import torch

torch.cuda.current_device()
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# <ipython-input-3-9e434df874e7> in <module>
#       1 import torch
#       2
# ----> 3 torch.cuda.current_device()
#
# ~/Library/Python/3.8/lib/python/site-packages/torch/cuda/__init__.py in current_device()
#     386 def current_device() -> int:
#     387     r"""Returns the index of a currently selected device."""
# --> 388     _lazy_init()
#     389     return torch._C._cuda_getDevice()
#     390
#
# ~/Library/Python/3.8/lib/python/site-packages/torch/cuda/__init__.py in _lazy_init()
#     162                 "multiprocessing, you must use the 'spawn' start method")
#     163         if not hasattr(torch._C, '_cuda_getDeviceCount'):
# --> 164             raise AssertionError("Torch not compiled with CUDA enabled")
#     165         if _cudart is None:
#     166             raise AssertionError(
#
# ...
